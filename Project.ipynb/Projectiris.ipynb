# %% [markdown]
# # Ronald A Fisher Iris Flower Project
#
#
# **Adedoyinsola Fifo**
#
# ***

# %% [markdown]
# # Question
#
# The project is to create a notebook investigating the variables and
# data points within the well-known iris flower data set associated
# with Ronald A Fisher.
#
# • In the notebook, you should discuss the classification of each
# variable within the data set according to common variable types
# and scales of measurement in mathematics, statistics, and Python.
# • Select, demonstrate, and explain the most appropriate summary
# statistics to describe each variable.
# • Select, demonstrate, and explain the most appropriate plot(s) for
# each variable.
# • The notebook should follow a cohesive narrative about the data
# set.

# %%
import pandas as pd
from sklearn.datasets import load_iris 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# # Importing Iris dataset
# For the program to run, make sure to copy both the notebbok and the data into your working folder
#
# ***

# %%
data = pd.read_csv('C:\\Users\\fifoa\\Downloads\\IRIS (1).csv')
data.columns = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# Summary of Iris Dataset

# %%
data.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# # Summary of each variable
# The write function will create the text file named 'iris_summary_stats.txt' where the summary of each variable will be saved

# %%
sepal_len = data['sepal_length'].describe()
print(sepal_len)

#sepal_len.to_csv('iris_summary_stats.txt', sep='\t')
with open('iris_summary_stats.txt', 'w') as fl:
    fl.write(sepal_len.to_csv(sep='\t')+'\n')
# Out:
# count    150.000000
# mean       5.843333
# std        0.828066
# min        4.300000
# 25%        5.100000
# 50%        5.800000
# 75%        6.400000
# max        7.900000
# Name: sepal_length, dtype: float64

# %%
sepal_wid = data['sepal_width'].describe()
print(sepal_wid)
with open('iris_summary_stats.txt', 'a+') as fl:
    fl.write(sepal_wid.to_csv(sep='\t')+'\n')
# Out:
# count    150.000000
# mean       3.054000
# std        0.433594
# min        2.000000
# 25%        2.800000
# 50%        3.000000
# 75%        3.300000
# max        4.400000
# Name: sepal_width, dtype: float64

# %%
petal_len = data['petal_length'].describe()
print(petal_len)
with open('iris_summary_stats.txt', 'a+') as fl:
    fl.write(petal_len.to_csv(sep='\t')+'\n')
# Out:
# count    150.000000
# mean       3.758667
# std        1.764420
# min        1.000000
# 25%        1.600000
# 50%        4.350000
# 75%        5.100000
# max        6.900000
# Name: petal_length, dtype: float64

# %%
petal_wid = data['petal_width'].describe()
print(petal_wid)
with open('iris_summary_stats.txt', 'a+') as fl:
    fl.write(petal_wid.to_csv(sep='\t')+'\n')
# Out:
# count    150.000000
# mean       1.198667
# std        0.763161
# min        0.100000
# 25%        0.300000
# 50%        1.300000
# 75%        1.800000
# max        2.500000
# Name: petal_width, dtype: float64

# %% [markdown]
# # Plotting Historgram for each variable
# The 'Savefig' function create a png file for each variable

# %%
sep_len = data['sepal_length']  # Corrected column name
plt.hist(sep_len)
plt.savefig('sep_len.png')

# %%
sep_wid = data['sepal_width']
plt.hist(sep_wid)
plt.savefig('sep_wid.png')

# %%
pet_len = data['petal_length']  
plt.hist(pet_len)
plt.savefig('pet_len.png')

# %%
pet_wid = data['petal_width']
plt.hist(pet_wid)
plt.savefig('pet_wid.png')

# %% [markdown]
# # Grouping and plotting the scatter plot for each pair of species

# %%
setosa_df = data[data['species'] == 'Iris-setosa']
setosa_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
sns.pairplot(setosa_df)

# %%
versicolor_df = data[data['species'] == 'Iris-versicolor']
versicolor_df.head()
# Out:
#     sepal_length  sepal_width  petal_length  petal_width          species
# 50           7.0          3.2           4.7          1.4  Iris-versicolor
# 51           6.4          3.2           4.5          1.5  Iris-versicolor
# 52           6.9          3.1           4.9          1.5  Iris-versicolor
# 53           5.5          2.3           4.0          1.3  Iris-versicolor
# 54           6.5          2.8           4.6          1.5  Iris-versicolor

# %%
sns.pairplot(versicolor_df)

# %%
virginica_df = data[data['species'] == 'Iris-virginica']
virginica_df.head()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 100           6.3          3.3           6.0          2.5  Iris-virginica
# 101           5.8          2.7           5.1          1.9  Iris-virginica
# 102           7.1          3.0           5.9          2.1  Iris-virginica
# 103           6.3          2.9           5.6          1.8  Iris-virginica
# 104           6.5          3.0           5.8          2.2  Iris-virginica

# %%
sns.pairplot(virginica_df)

# %% [markdown]
# # Other Analysis

# %%
sns.pairplot(data, hue='species')

# %%
data.groupby(['species']).agg('count')
# Out:
#                  sepal_length  sepal_width  petal_length  petal_width
# species
# Iris-setosa                50           50            50           50
# Iris-versicolor            50           50            50           50
# Iris-virginica             50           50            50           50
